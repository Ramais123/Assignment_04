# %%
print("Control Flow For Console")

import random

NUM_ROUNDS = 5
MIN_VALUE = 1
MAX_VALUE = 100

def main():
    print("Welcome to the High-Low Game!")
    print("--------------------------------")

    score = 0

    for round_number in range(1, NUM_ROUNDS + 1):
        print(f"Round {round_number}")
        user_number = random.randint(MIN_VALUE, MAX_VALUE)
        computer_number = random.randint(MIN_VALUE, MAX_VALUE)

        print(f"Your number is {user_number}")
        guess = input("Do you think your number is higher or lower than the computer's?: ").strip().lower()

        while guess not in ['higher', 'lower']:
            guess = input("Please enter either higher or lower: ").strip().lower()

        correct = False
        if guess == "higher" and user_number > computer_number:
            correct = True
        elif guess == "lower" and user_number < computer_number:
            correct = True

        if correct:
            print(f"You were right! The computer's number was {computer_number}")
            score += 1
        else:
            print(f"Aww, that's incorrect. The computer's number was {computer_number}")

        print(f"Your score is now {score}\n")

    print("Thanks for playing!")

    if score == NUM_ROUNDS:
        print("Wow! You played perfectly!")
    elif score >= NUM_ROUNDS // 2:
        print("Good job, you played really well!")
    else:
        print("Better luck next time!")

if __name__ == '__main__':
    main()
# Out:
# handout
# Welcome to the High-Low Game!
# --------------------------------
# Round 1
# Your number is 35
# Do you think your number is higher or lower than the computer's?: lower
# You were right! The computer's number was 54
# Your score is now 1
#
# Round 2
# Your number is 68
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 50
# Your score is now 2
#
# Round 3
# Your number is 71
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 40
# Your score is now 3
#
# Round 4
# Your number is 85
# Do you think your number is higher or lower than the computer's?: ower
# Please enter either higher or lower: lower
# Aww, that's incorrect. The computer's number was 49
# Your score is now 3
#
# Round 5
# Your number is 86
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 55
# Your score is now 4
#
# Thanks for playing!
# Good job, you played really well!

# %%
print("intro to python ")

def main():
    earth_weight = float(input("Enter a weight on Earth: "))
    planet = input("Enter a planet: ")

    gravity_factors = {
        "Mercury": 0.376,
        "Venus": 0.889,
        "Mars": 0.378,
        "Jupiter": 2.36,
        "Saturn": 1.081,
        "Uranus": 0.815,
        "Neptune": 1.14
    }

    if planet in gravity_factors:
        planet_weight = earth_weight * gravity_factors[planet]
        planet_weight = round(planet_weight, 2)
        print(f"The equivalent weight on {planet}: {planet_weight}")
    else:
        print("Unknown planet. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# intro to python
# Enter a weight on Earth: 150
# Enter a planet: Jupiter
# The equivalent weight on Jupiter: 354.0

# %%
print("")

def list_practice():
    fruit_list = ['apple', 'banana', 'orange', 'grape', 'pineapple']
    print("Length of the list:", len(fruit_list))
    fruit_list.append('mango')
    print("Updated list:", fruit_list)

def access_element(lst, index):
    if 0 <= index < len(lst):
        return lst[index]
    else:
        return "Index out of range."

def modify_element(lst, index, new_value):
    if 0 <= index < len(lst):
        lst[index] = new_value
        return "Element modified successfully."
    else:
        return "Index out of range."

def slice_list(lst, start, end):
    try:
        return lst[start:end]
    except:
        return "Invalid indices."

def index_game():
    my_list = ['dog', 'cat', 'bird', 'fish', 'hamster']
    print("Initial list:", my_list)

    while True:
        print("\nChoose an operation: access / modify / slice / quit")
        action = input("Your choice: ").strip().lower()

        if action == 'access':
            index = int(input("Enter index to access: "))
            result = access_element(my_list, index)
            print("Result:", result)

        elif action == 'modify':
            index = int(input("Enter index to modify: "))
            new_value = input("Enter new value: ")
            result = modify_element(my_list, index, new_value)
            print(result)
            print("Updated list:", my_list)

        elif action == 'slice':
            start = int(input("Enter start index: "))
            end = int(input("Enter end index: "))
            result = slice_list(my_list, start, end)
            print("Sliced list:", result)

        elif action == 'quit':
            print("Thanks for playing!")
            break

        else:
            print("Invalid option. Try again.")

def main():
    print("== List Practice ==")
    list_practice()
    print("\n== Index Game ==")
    index_game()

if __name__ == "__main__":
    main()
# Out:
# == List Practice ==
# Length of the list: 5
# Updated list: ['apple', 'banana', 'orange', 'grape', 'pineapple', 'mango']
#
# == Index Game ==
# Initial list: ['dog', 'cat', 'bird', 'fish', 'hamster']
#
# Choose an operation: access / modify / slice / quit
# Your choice: modify
# Enter index to modify: 3
# Enter new value: pangue
# Your choice:
# Element modified successfully.
# Updated list: ['dog', 'cat', 'bird', 'pangue', 'hamster']
#
# Choose an operation: access / modify / slice / quit
# Invalid option. Try again.
#
# Choose an operation: access / modify / slice / quit
# Your choice: slice
# Enter start index: 1
# Enter end index: 3
# Sliced list: ['cat', 'bird']
#
# Choose an operation: access / modify / slice / quit
# Your choice: access
# Enter index to access: 4
# Result: hamster
#
# Choose an operation: access / modify / slice / quit
# Your choice: quit
# Thanks for playing!
